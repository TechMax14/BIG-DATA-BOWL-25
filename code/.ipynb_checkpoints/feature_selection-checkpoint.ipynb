# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go 
import numpy as np
from scipy.spatial import Voronoi, voronoi_plot_2d
from IPython.display import display
import time
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor


# Load the datasets (ensure correct paths and files)
train_features = pd.read_csv('../data/processed_data/merged_train_data.csv')
test_features = pd.read_csv('../data/processed_data/week_9_test_features.csv')

#train_labels = pd.read_csv('../data/processed_data/merged_train_target.csv')

# %%
train_features.describe()
# Out:
#              gameId        playId     play_type          week       quarter  \
# count  1.404000e+04  14040.000000  14040.000000  14040.000000  14040.000000
# mean   2.022098e+09   2029.350000      0.564031      4.405271      2.573647
# std    4.859946e+03   1186.104566      0.495901      2.285767      1.136958
# min    2.022091e+09     54.000000      0.000000      1.000000      1.000000
# 25%    2.022092e+09    994.750000      0.000000      2.000000      2.000000
# 50%    2.022100e+09   2022.000000      1.000000      4.000000      3.000000
# 75%    2.022102e+09   3032.000000      1.000000      6.000000      4.000000
# max    2.022103e+09   5120.000000      1.000000      8.000000      5.000000
#
#        gameClockSeconds  gameQuarterWeight          down     yardsToGo  \
# count      14040.000000       14040.000000  14040.000000  14040.000000
# mean         430.628419           1.487650      1.783262      8.461752
# ...

# %%
# OBSERVE THE FEATURE CORRELATION HEAT MAP BEFORE REFINING

corr = train_features.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()
# Out:
# C:\Users\fishm\AppData\Local\Temp\ipykernel_1772\1400468344.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = train_features.corr()

# %%
# DROP UNNECESSARY COLUMNS
print(train_features.columns)

# Define the columns to drop
columns_to_drop = ['gameId', 'playId', 'isDropback', 'week', 'yardsGained', 'receiverAlignment']

# Drop only the columns that exist in train_features
train_features = train_features.drop(columns=[col for col in columns_to_drop if col in train_features.columns])

# # Create a mapping for receiverAlignment
# alignment_mapping = {
#     '0x0': 0,
#     '1x0': 1,
#     '1x1': 2,
#     '2x0': 3,
#     '2x1': 4,
#     '2x2': 5,
#     '3x0': 6,
#     '3x1': 7,
#     '3x2': 8,
#     '3x3': 9,
#     '4x1': 10,
#     '4x2':11
# }

# # Apply the mapping
# train_features['receiverAlignment'] = train_features['receiverAlignment'].map(alignment_mapping)

print(train_features.columns)
# Out:
# Index(['gameId', 'playId', 'play_type', 'week', 'quarter', 'gameClockSeconds',
#        'gameQuarterWeight', 'down', 'yardsToGo', 'yardsGained',
#        'expectedPoints', 'expectedPointsAdded', 'absoluteYardlineNumber',
#        'offenseFormation', 'inMotionAtBallSnap', 'isDropback',
#        'field_position_weight', 'scoreDifferential', 'playSuccessWeight',
#        'possessionTeamWinProbability', 'possessionTeamImpact',
#        'opponentTeamImpact', 'receiverAlignment', 'players_in_box_count',
#        'mismatchFound', 'motion_type', 'motion_player_count',
#        'pre_snap_time_duration'],
#       dtype='object')
# Index(['play_type', 'quarter', 'gameClockSeconds', 'gameQuarterWeight', 'down',
#        'yardsToGo', 'expectedPoints', 'expectedPointsAdded',
#        'absoluteYardlineNumber', 'offenseFormation', 'inMotionAtBallSnap',
#        'field_position_weight', 'scoreDifferential', 'playSuccessWeight',
#        'possessionTeamWinProbability', 'possessionTeamImpact',
# ...

# %%
# Remove 4 rows missing values
train_features = train_features.dropna(subset=['offenseFormation'])
# Remove 4 rows missing values
train_features = train_features.dropna(subset=['pre_snap_time_duration'])

# Assuming train_features contains all your features and 'pff_manZone' is the column you want to predict
train_labels = train_features['play_type']

# Drop 'pff_manZone' from train_features to avoid data leakage
train_features = train_features.drop(columns=['play_type'])

target_corr = train_features.corrwith(train_labels)  # Assuming `train_labels` contains your target variables
print(target_corr)
# Out:
# quarter                         0.007623
# gameClockSeconds               -0.075806
# gameQuarterWeight               0.027836
# down                            0.194118
# yardsToGo                       0.115384
# expectedPoints                 -0.144606
# expectedPointsAdded             0.046005
# absoluteYardlineNumber         -0.007993
# offenseFormation               -0.152572
# inMotionAtBallSnap             -0.091650
# field_position_weight          -0.058326
# scoreDifferential              -0.135183
# playSuccessWeight               0.045539
# possessionTeamWinProbability   -0.163263
# possessionTeamImpact            0.018480
# opponentTeamImpact             -0.018480
# players_in_box_count           -0.334968
# mismatchFound                   0.656984
# motion_type                    -0.017050
# motion_player_count            -0.015748
# pre_snap_time_duration          0.016091
# dtype: float64

# %%
# List of features to remove due to low correlation
features_to_remove = [
    'absoluteYardlineNumber',
    'quarter',
    'motion_player_count'
]

train_features = train_features.drop(columns=features_to_remove)
test_features = test_features.drop(columns=features_to_remove)

# Calculate VIF for each feature
X = train_features # Without the target
#X = X.dropna(subset=['pre_snap_time_duration']) # Removing 4 NA rows
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
#                          Feature        VIF
# 0               gameClockSeconds   3.746402
# 1              gameQuarterWeight  12.218393
# 2                           down   9.477383
# 3                      yardsToGo   6.193057
# 4                 expectedPoints  24.744587
# 5            expectedPointsAdded  28.691269
# 6               offenseFormation   7.192627
# 7             inMotionAtBallSnap   1.469070
# 8          field_position_weight  34.139373
# 9              scoreDifferential   4.938961
# 10             playSuccessWeight  39.872010
# 11  possessionTeamWinProbability  19.407025
# 12          possessionTeamImpact        inf
# 13            opponentTeamImpact        inf
# 14          players_in_box_count  29.917946
# 15                 mismatchFound   1.884824
# 16                   motion_type   1.792711
# 17        pre_snap_time_duration   8.108574
# ...

# %%
# List of features to remove due to low correlation
features_to_remove = [
    'expectedPoints',
    'expectedPointsAdded',
    'field_position_weight',
    'playSuccessWeight',
    'possessionTeamWinProbability',
    'possessionTeamImpact',
    'opponentTeamImpact',
    'players_in_box_count',
]

train_features = train_features.drop(columns=features_to_remove)
test_features = test_features.drop(columns=features_to_remove)

# Calculate VIF for each feature
X = train_features # Without the target
#X = X.dropna(subset=['pre_snap_time_duration']) # Removing 4 NA rows
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
#                   Feature       VIF
# 0        gameClockSeconds  3.411948
# 1       gameQuarterWeight  9.679017
# 2                    down  5.671957
# 3               yardsToGo  5.241764
# 4        offenseFormation  6.138079
# 5      inMotionAtBallSnap  1.411162
# 6       scoreDifferential  1.055431
# 7           mismatchFound  1.853131
# 8             motion_type  1.791717
# 9  pre_snap_time_duration  7.452156

# %%
# Exporting training and testing without NA values and VIF features
train_features.to_csv('../data/processed_data/training_features.csv', index=False)
train_labels.to_csv('../data/processed_data/training_target_features.csv', index=False)

# %%
# Remove 4 rows missing values
test_features = test_features.dropna(subset=['offenseFormation'])
# Remove 4 rows missing values
test_features = test_features.dropna(subset=['pre_snap_time_duration'])
print(test_features.shape)
# Out:
# (1461, 16)

# %%
test_features.to_csv('../data/processed_data/testing_features.csv', index=False)
