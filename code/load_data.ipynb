# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import numpy as np
from scipy.spatial import Voronoi, voronoi_plot_2d
from IPython.display import display
import time
from sklearn.utils import shuffle
from joblib import Parallel, delayed

# Import custom modules for data preparation, preprocessing, cleaning, and feature extraction
from prepare_data import aggregate_play_types, aggregate_play_level_features, final_merge
from preprocess_tracking_data import filter_for_presnap
from clean_data import clean_data, downcast_ints_and_floats, convert_to_DICT
from defensive_features import get_defensive_features
from offensive_features import get_offensive_features
from constants import RUN_PASS_DICT, MOTION_CAT_DICT, OFFENSIVE_FORMATION_DICT, REC_ALIGNMENT_DICT

# Uncomment these lines during development to reload custom modules automatically after changes
# %load_ext autoreload
# %autoreload 2

# Load the datasets (ensure file paths are correct)
games_df = pd.read_csv('../data/games.csv')          # Game-level data
plays_df = pd.read_csv('../data/plays.csv')          # Play-level data
players_df = pd.read_csv('../data/players.csv')      # Player metadata
player_play_df = pd.read_csv('../data/player_play.csv')  # Player-play metadata
fps_df = pd.read_csv('../data/FINAL_FPS.csv')        # FPS data
    
# Initialize an empty list to store the DataFrames for each week
def_features_data = []
off_features_data = []

# Aggregate play types (e.g., run, pass) and merge play data with other game-level information
df = aggregate_play_types(plays_df, player_play_df, games_df)

# Aggregate play-level features such as yards gained, possession, etc.
agg_df = aggregate_play_level_features(df, fps_df, plays_df)

# Loop over weeks 1 to 9
for week in range(1, 10):  # week goes from 1 to 9
    print(f"INFO: [ PROCESSING WEEK {week} ]")
    start_time = time.time()

    # Filter the tracking data to focus on pre-snap movements for the specified week
    presnap_tracking = filter_for_presnap(week, players_df).copy()

    # Clean the tracking data to remove invalid entries or apply transformations
    df_clean = clean_data(presnap_tracking)

    # Extract defensive features, such as coverage schemes, based on the cleaned data
    def_features = get_defensive_features(df_clean, agg_df, players_df, player_play_df)

    # Extract offensive features, such as formations and pre-snap motion
    off_features = get_offensive_features(df_clean, player_play_df)
    
    # Append the final dataframe for the current week to the list
    def_features_data.append(def_features)
    off_features_data.append(off_features)

    # Record the end time and calculate the duration of the data processing
    end_time = time.time()
    duration = end_time - start_time

    # Print information about the process duration and the number of rows in the final dataset
    print(f"INFO: Tracking Features took {duration:.4f} seconds to process week {week} tracking data.\n")

def_features_data = pd.concat(def_features_data, ignore_index=True)
off_features_data = pd.concat(off_features_data, ignore_index=True)

# Merge aggregated play-level features with defensive and offensive features
merged_df = final_merge(agg_df, def_features_data, off_features_data).copy()

# Convert categorical features (e.g., run/pass type, motion categories, formations) into dictionaries
final_df = convert_to_DICT(merged_df, RUN_PASS_DICT, MOTION_CAT_DICT, OFFENSIVE_FORMATION_DICT, REC_ALIGNMENT_DICT)

# Downcast final df for training
final_df_clean = downcast_ints_and_floats(final_df).copy()

# Shuffle Data for training
final_df_shuffle = shuffle(final_df_clean, random_state=42)

# Select training data for weeks 1 through 8
training_data = final_df_shuffle[final_df_shuffle['week'].isin(range(1, 9))]

# Create the target for training data
train_labels = training_data['play_type']

# Split week 9 for testing the model
week_9_data = final_df_shuffle[final_df_shuffle['week'] == 9]

# Remove target for testing data 
testing_data = week_9_data.drop(columns=['play_type'])

# Create the target for training data
test_labels = week_9_data['play_type']

end_time = time.time()
duration = end_time - start_time

print(f"INFO: [ TRAINING DATA ROWS: {training_data.shape[0]} rows ]")
print(f"INFO: [ TESTING DATA ROWS:  {testing_data.shape[0]}  rows ]")
print(f"INFO: Data for all weeks (1-9) is combined into one DataFrame with {final_df_clean.shape[0]} rows. (Runtime: {duration:.4f})")

print(f"Total shape: {final_df_clean.shape}")
print(f"Training shape: {training_data.shape}")
print(f"Train Target shape {train_labels.shape}")
print(f"Testing shape: {testing_data.shape}")
print(f"Test Target shape {test_labels.shape}")

final_df_shuffle.to_csv(f'../data/processed_data/all_weeks_processed_data.csv', index=False)
training_data.to_csv(f'../data/processed_data/training_data.csv', index=False)
testing_data.to_csv(f'../data/processed_data/testing_data.csv', index=False)
train_labels.to_csv(f'../data/processed_data/train_labels.csv', index=False)
test_labels.to_csv(f'../data/processed_data/test_labels.csv', index=False)
# Out:
# INFO: [ START OF DATA LOADING]
# INFO: Filtering for run and pass plays...
# INFO: Found 8728 unique PASS plays...
# INFO: Found 6788 unique RUN plays...
# INFO: Combining run-pass dataframes...
# INFO: Combined DataFrame contains 15516 unique plays (pass and run), with week column added.
# INFO: Merging FPS df for play level features.
# INFO: Merged DataFrame contains 15516 rows and 23 columns.
#
# INFO: [ PROCESSING WEEK 1 ]
# INFO: Filtering 7104700 rows of tracking data for pre-snap frames in week 1...
# INFO: Found 4692460 pre-snap frames of tracking data in week 1.
# INFO: Found 1952 plays of tracking data in week 1.
# INFO: Merging player position data into tracking data...
# WARN: Found 204020 players without position information.
# INFO: Merged position data into tracking data. New shape: (4692460, 19)
# INFO: Transforming orientation and direction angles so that 0° points from left to right, and increasing angle goes counterclockwise...
# INFO: Flipping plays so that they all run from left to right...
# INFO: Converting geometry variables from floats to int...
# INFO: Memory usage reduced from 2758494056 to 2589565496
# INFO: Downcasting integers and floats...
# INFO: Memory usage reduced from 2589565496 to 2326787736
# INFO: Processing defensive features...
# INFO: Idenitfying a count of defensive players in the box pre-snap...
# INFO: Extracting defenders with primary matchups...
# INFO: Identifying defensive mismatches...
# INFO: Defensive Feature functions ran in 8.5437 seconds
# INFO: Extracting offensive features: motion categorization and motion player count...
# INFO: Calculating time from huddle break to snap...
# INFO: Offensive Feature functions ran in 12.2344 seconds
# INFO: Tracking Features took 70.0565 seconds to process week 1 tracking data.
#
# INFO: [ PROCESSING WEEK 2 ]
# INFO: Filtering 6704339 rows of tracking data for pre-snap frames in week 2...
# INFO: Found 4460298 pre-snap frames of tracking data in week 2.
# INFO: Found 1809 plays of tracking data in week 2.
# INFO: Merging player position data into tracking data...
# WARN: Found 193926 players without position information.
# INFO: Merged position data into tracking data. New shape: (4460298, 19)
# INFO: Transforming orientation and direction angles so that 0° points from left to right, and increasing angle goes counterclockwise...
# INFO: Flipping plays so that they all run from left to right...
# INFO: Converting geometry variables from floats to int...
# INFO: Memory usage reduced from 2621717607 to 2461146879
# INFO: Downcasting integers and floats...
# INFO: Memory usage reduced from 2461146879 to 2211370191
# INFO: Processing defensive features...
# INFO: Idenitfying a count of defensive players in the box pre-snap...
# INFO: Extracting defenders with primary matchups...
# INFO: Identifying defensive mismatches...
# INFO: Defensive Feature functions ran in 8.3175 seconds
# INFO: Extracting offensive features: motion categorization and motion player count...
# INFO: Calculating time from huddle break to snap...
# INFO: Offensive Feature functions ran in 10.6287 seconds
# INFO: Tracking Features took 63.9235 seconds to process week 2 tracking data.
#
# INFO: [ PROCESSING WEEK 3 ]
# INFO: Filtering 7129195 rows of tracking data for pre-snap frames in week 3...
# INFO: Found 4702718 pre-snap frames of tracking data in week 3.
# INFO: Found 1959 plays of tracking data in week 3.
# INFO: Merging player position data into tracking data...
# WARN: Found 204466 players without position information.
# INFO: Merged position data into tracking data. New shape: (4702718, 19)
# INFO: Transforming orientation and direction angles so that 0° points from left to right, and increasing angle goes counterclockwise...
# INFO: Flipping plays so that they all run from left to right...
# INFO: Converting geometry variables from floats to int...
# INFO: Memory usage reduced from 2764607193 to 2595309345
# INFO: Downcasting integers and floats...
# INFO: Memory usage reduced from 2595309345 to 2331957137
# INFO: Processing defensive features...
# INFO: Idenitfying a count of defensive players in the box pre-snap...
# INFO: Extracting defenders with primary matchups...
# INFO: Identifying defensive mismatches...
# INFO: Defensive Feature functions ran in 8.6425 seconds
# INFO: Extracting offensive features: motion categorization and motion player count...
# INFO: Calculating time from huddle break to snap...
# INFO: Offensive Feature functions ran in 10.8288 seconds
# INFO: Tracking Features took 67.6597 seconds to process week 3 tracking data.
#
# INFO: [ PROCESSING WEEK 4 ]
# INFO: Filtering 6747556 rows of tracking data for pre-snap frames in week 4...
# INFO: Found 4463334 pre-snap frames of tracking data in week 4.
# INFO: Found 1830 plays of tracking data in week 4.
# INFO: Merging player position data into tracking data...
# WARN: Found 194058 players without position information.
# INFO: Merged position data into tracking data. New shape: (4463334, 19)
# INFO: Transforming orientation and direction angles so that 0° points from left to right, and increasing angle goes counterclockwise...
# INFO: Flipping plays so that they all run from left to right...
# INFO: Converting geometry variables from floats to int...
# INFO: Memory usage reduced from 2623460037 to 2462780013
# INFO: Downcasting integers and floats...
# INFO: Memory usage reduced from 2462780013 to 2212833309
# INFO: Processing defensive features...
# INFO: Idenitfying a count of defensive players in the box pre-snap...
# INFO: Extracting defenders with primary matchups...
# INFO: Identifying defensive mismatches...
# INFO: Defensive Feature functions ran in 8.3476 seconds
# INFO: Extracting offensive features: motion categorization and motion player count...
# INFO: Calculating time from huddle break to snap...
# INFO: Offensive Feature functions ran in 10.3284 seconds
# INFO: Tracking Features took 63.2541 seconds to process week 4 tracking data.
#
# INFO: [ PROCESSING WEEK 5 ]
# INFO: Filtering 7103067 rows of tracking data for pre-snap frames in week 5...
# INFO: Found 4736183 pre-snap frames of tracking data in week 5.
# INFO: Found 1906 plays of tracking data in week 5.
# INFO: Merging player position data into tracking data...
# WARN: Found 205921 players without position information.
# INFO: Merged position data into tracking data. New shape: (4736183, 19)
# INFO: Transforming orientation and direction angles so that 0° points from left to right, and increasing angle goes counterclockwise...
# INFO: Flipping plays so that they all run from left to right...
# INFO: Converting geometry variables from floats to int...
# INFO: Memory usage reduced from 2783943054 to 2613440466
# INFO: Downcasting integers and floats...
# INFO: Memory usage reduced from 2613440466 to 2348214218
# INFO: Processing defensive features...
# INFO: Idenitfying a count of defensive players in the box pre-snap...
# INFO: Extracting defenders with primary matchups...
# INFO: Identifying defensive mismatches...
# INFO: Defensive Feature functions ran in 8.4555 seconds
# INFO: Extracting offensive features: motion categorization and motion player count...
# INFO: Calculating time from huddle break to snap...
# INFO: Offensive Feature functions ran in 10.6196 seconds
# INFO: Tracking Features took 67.8916 seconds to process week 5 tracking data.
#
# INFO: [ PROCESSING WEEK 6 ]
# INFO: Filtering 6239486 rows of tracking data for pre-snap frames in week 6...
# INFO: Found 4154352 pre-snap frames of tracking data in week 6.
# INFO: Found 1697 plays of tracking data in week 6.
# INFO: Merging player position data into tracking data...
# WARN: Found 180624 players without position information.
# INFO: Merged position data into tracking data. New shape: (4154352, 19)
# INFO: Transforming orientation and direction angles so that 0° points from left to right, and increasing angle goes counterclockwise...
# INFO: Flipping plays so that they all run from left to right...
# INFO: Converting geometry variables from floats to int...
# INFO: Memory usage reduced from 2442102028 to 2292545356
# INFO: Downcasting integers and floats...
# INFO: Memory usage reduced from 2292545356 to 2059901644
# INFO: Processing defensive features...
# INFO: Idenitfying a count of defensive players in the box pre-snap...
# INFO: Extracting defenders with primary matchups...
# INFO: Identifying defensive mismatches...
# INFO: Defensive Feature functions ran in 8.0753 seconds
# INFO: Extracting offensive features: motion categorization and motion player count...
# INFO: Calculating time from huddle break to snap...
# INFO: Offensive Feature functions ran in 9.4699 seconds
# INFO: Tracking Features took 59.0634 seconds to process week 6 tracking data.
#
# INFO: [ PROCESSING WEEK 7 ]
# INFO: Filtering 6023631 rows of tracking data for pre-snap frames in week 7...
# INFO: Found 3951630 pre-snap frames of tracking data in week 7.
# INFO: Found 1665 plays of tracking data in week 7.
# INFO: Merging player position data into tracking data...
# WARN: Found 171810 players without position information.
# INFO: Merged position data into tracking data. New shape: (3951630, 19)
# INFO: Transforming orientation and direction angles so that 0° points from left to right, and increasing angle goes counterclockwise...
# INFO: Flipping plays so that they all run from left to right...
# INFO: Converting geometry variables from floats to int...
# INFO: Memory usage reduced from 2323287852 to 2181029172
# INFO: Downcasting integers and floats...
# INFO: Memory usage reduced from 2181029172 to 1959737892
# INFO: Processing defensive features...
# INFO: Idenitfying a count of defensive players in the box pre-snap...
# INFO: Extracting defenders with primary matchups...
# INFO: Identifying defensive mismatches...
# INFO: Defensive Feature functions ran in 7.8505 seconds
# INFO: Extracting offensive features: motion categorization and motion player count...
# INFO: Calculating time from huddle break to snap...
# INFO: Offensive Feature functions ran in 9.3199 seconds
# INFO: Tracking Features took 56.5186 seconds to process week 7 tracking data.
#
# INFO: [ PROCESSING WEEK 8 ]
# INFO: Filtering 6603714 rows of tracking data for pre-snap frames in week 8...
# INFO: Found 4287844 pre-snap frames of tracking data in week 8.
# INFO: Found 1771 plays of tracking data in week 8.
# INFO: Merging player position data into tracking data...
# WARN: Found 186428 players without position information.
# INFO: Merged position data into tracking data. New shape: (4287844, 19)
# INFO: Transforming orientation and direction angles so that 0° points from left to right, and increasing angle goes counterclockwise...
# INFO: Flipping plays so that they all run from left to right...
# INFO: Converting geometry variables from floats to int...
# INFO: Memory usage reduced from 2520439404 to 2366077020
# INFO: Downcasting integers and floats...
# INFO: Memory usage reduced from 2366077020 to 2125957756
# INFO: Processing defensive features...
# INFO: Idenitfying a count of defensive players in the box pre-snap...
# INFO: Extracting defenders with primary matchups...
# INFO: Identifying defensive mismatches...
# INFO: Defensive Feature functions ran in 8.1374 seconds
# INFO: Extracting offensive features: motion categorization and motion player count...
# INFO: Calculating time from huddle break to snap...
# INFO: Offensive Feature functions ran in 9.7579 seconds
# INFO: Tracking Features took 61.3635 seconds to process week 8 tracking data.
#
# INFO: [ PROCESSING WEEK 9 ]
# INFO: Filtering 5671685 rows of tracking data for pre-snap frames in week 9...
# INFO: Found 3729473 pre-snap frames of tracking data in week 9.
# INFO: Found 1535 plays of tracking data in week 9.
# INFO: Merging player position data into tracking data...
# WARN: Found 162151 players without position information.
# INFO: Merged position data into tracking data. New shape: (3729473, 19)
# INFO: Transforming orientation and direction angles so that 0° points from left to right, and increasing angle goes counterclockwise...
# INFO: Flipping plays so that they all run from left to right...
# INFO: Converting geometry variables from floats to int...
# INFO: Memory usage reduced from 2192096002 to 2057834974
# INFO: Downcasting integers and floats...
# INFO: Memory usage reduced from 2057834974 to 1848984486
# INFO: Processing defensive features...
# INFO: Idenitfying a count of defensive players in the box pre-snap...
# INFO: Extracting defenders with primary matchups...
# INFO: Identifying defensive mismatches...
# INFO: Defensive Feature functions ran in 7.5308 seconds
# INFO: Extracting offensive features: motion categorization and motion player count...
# INFO: Calculating time from huddle break to snap...
# INFO: Offensive Feature functions ran in 8.5318 seconds
# INFO: Tracking Features took 54.4678 seconds to process week 9 tracking data.
#
# INFO: Downcasting integers and floats...
# INFO: Memory usage reduced from 3413520 to 1101636
# INFO: [ TRAINING DATA ROWS: 14040 rows ]
# INFO: [ TESTING DATA ROWS:  1476  rows ]
# INFO: Data for all weeks (1-9) is combined into one DataFrame with 15516 rows. (Runtime: 54.5274)
# Total shape: (15516, 28)
# Training shape: (14040, 28)
# Train Target shape (14040,)
# Testing shape: (1476, 27)
# Test Target shape (1476,)

# %%
# Check for missing values
print(final_df_shuffle.isna().sum())  # Shows the number of NaN values for each column
# Out:
# gameId                          0
# playId                          0
# play_type                       0
# week                            0
# quarter                         0
# gameClockSeconds                0
# gameQuarterWeight               0
# down                            0
# yardsToGo                       0
# yardsGained                     0
# expectedPoints                  0
# expectedPointsAdded             0
# absoluteYardlineNumber          0
# offenseFormation                0
# inMotionAtBallSnap              0
# isDropback                      0
# field_position_weight           0
# scoreDifferential               0
# playSuccessWeight               0
# possessionTeamWinProbability    0
# possessionTeamImpact            0
# opponentTeamImpact              0
# receiverAlignment               0
# players_in_box_count            0
# mismatchFound                   0
# motion_type                     0
# motion_player_count             0
# pre_snap_time_duration          0
# dtype: int64
